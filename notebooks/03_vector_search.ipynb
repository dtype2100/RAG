# %%
# https://docs.langchain.com/oss/python/integrations/splitters/recursive_text_splitter
from langchain_text_splitters import RecursiveCharacterTextSplitter
from qdrant_client import QdrantClient
from langchain_qdrant import QdrantVectorStore
from qdrant_client.models import Distance, VectorParams
# https://docs.langchain.com/oss/python/integrations/splitters/markdown_header_metadata_splitter
from langchain_text_splitters import MarkdownHeaderTextSplitter
from pathlib import Path
from tqdm import tqdm
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_huggingface.embeddings import HuggingFaceEndpointEmbeddings
# Out:
# c:\Users\jw160\.local\share\mamba\envs\agent\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.1.0)/charset_normalizer (3.4.6) doesn't match a supported version!
#   warnings.warn(

# %%
client = QdrantClient(url="http://localhost:6333")
# client = QdrantClient(":memory:")

embeddings = HuggingFaceEndpointEmbeddings(client="http://localhost:8080")
    
vector_store = QdrantVectorStore(
    client=client,
    collection_name="test",
    embedding=embeddings,
)

retriever = vector_store.as_retriever(
    search_type="similarity_score_threshold",
    search_kwargs={"score_threshold": 0.3},
)

# %%
print(retriever.invoke("혜움 연혁 알려줘"))
# Out:
# [Document(metadata={'source': 'https___www_heum_ai_ko_o_115332.md', 'Header 1': 'https://www.heum.ai/ko/o/115332', 'Header 3': '**PO/PM(주니어/미들/시니어/리더/트라이브리더/CPO)**', '_id': '14621d40-9ced-4281-a1f9-791c84676aad', '_collection_name': 'test'}, page_content='* 서비스 기획 혹은 리딩'), Document(metadata={'source': 'https___www_heum_ai_o_115332.md', 'Header 1': 'https://www.heum.ai/o/115332', 'Header 3': '**PO/PM(주니어/미들/시니어/리더/트라이브리더/CPO)**', '_id': '9b32d7d2-d002-4693-a28b-c64748a5631f', '_collection_name': 'test'}, page_content='* 서비스 기획 혹은 리딩'), Document(metadata={'source': 'https___www_heum_ai_o_115332.md', 'Header 1': 'https://www.heum.ai/o/115332', 'Header 3': '**PO/PM(주니어/미들/시니어/리더/트라이브리더/CPO)**', '_id': '2eabdcaa-4a9a-4cdf-a4fe-6c985e55e23e', '_collection_name': 'test'}, page_content='* 서비스 기획 혹은 리딩'), Document(metadata={'source': 'https___www_heum_ai_ko_o_115332.md', 'Header 1': 'https://www.heum.ai/ko/o/115332', 'Header 3': '**PO/PM(주니어/미들/시니어/리더/트라이브리더/CPO)**', '_id': 'd7373804-f1ea-4610-8ccb-1f66c0adb2bd', '_collection_name': 'test'}, page_content='* 서비스 기획 혹은 리딩')]

# %%
result = retriever.invoke("채용공고")

# %%
result
# Out:
# [Document(metadata={'source': 'https___www_heum_ai_ko_o_115332.md', 'Header 1': 'https://www.heum.ai/ko/o/115332', 'Header 3': '**PO/PM(주니어/미들/시니어/리더/트라이브리더/CPO)**', '_id': 'd7373804-f1ea-4610-8ccb-1f66c0adb2bd', '_collection_name': 'test'}, page_content='* 서비스 기획 혹은 리딩'),
#  Document(metadata={'source': 'https___www_heum_ai_o_115332.md', 'Header 1': 'https://www.heum.ai/o/115332', 'Header 3': '**PO/PM(주니어/미들/시니어/리더/트라이브리더/CPO)**', '_id': '2eabdcaa-4a9a-4cdf-a4fe-6c985e55e23e', '_collection_name': 'test'}, page_content='* 서비스 기획 혹은 리딩'),
#  Document(metadata={'source': 'https___www_heum_ai_o_115332.md', 'Header 1': 'https://www.heum.ai/o/115332', 'Header 3': '**PO/PM(주니어/미들/시니어/리더/트라이브리더/CPO)**', '_id': '9b32d7d2-d002-4693-a28b-c64748a5631f', '_collection_name': 'test'}, page_content='* 서비스 기획 혹은 리딩'),
#  Document(metadata={'source': 'https___www_heum_ai_ko_o_115332.md', 'Header 1': 'https://www.heum.ai/ko/o/115332', 'Header 3': '**PO/PM(주니어/미들/시니어/리더/트라이브리더/CPO)**', '_id': '14621d40-9ced-4281-a1f9-791c84676aad', '_collection_name': 'test'}, page_content='* 서비스 기획 혹은 리딩')]

# %%
result[0].metadata
# Out:
# {'source': 'https___www_heum_ai_ko_o_115332.md',
#  'Header 1': 'https://www.heum.ai/ko/o/115332',
#  'Header 3': '**PO/PM(주니어/미들/시니어/리더/트라이브리더/CPO)**',
#  '_id': '14621d40-9ced-4281-a1f9-791c84676aad',
#  '_collection_name': 'test'}

# %%
result[0].page_content
# Out:
# '* 서비스 기획 혹은 리딩'
